# %% [markdown]
# # The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Data explained

# %% [markdown]
# In order to solve bussines problem that I explained in first section I will retreat Dara using Foursquare API. As free account is limited to 100, I made two calls with starting location on main square of each city and radius of 1500 meters which is approximately maximum walking distance for tourists and visitors (main target group of the company) and in same time that are covers most of points of interest in city centres.

# %% [markdown]
# Data that will be retreaved are:
# 1. Name of the vanue
# 2. Venue ID
# 3. Latitude
# 4. Longitude

# %% [markdown]
# Raw data will be in 2 tables. One for Belgrade and one for Zagreb. Using this data we can answer questions of business problem: numbe of vanues, location, density of vanues and find best location(s
